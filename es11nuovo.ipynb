# %% [markdown]
# # Esercitazione 11

# %%
#Librerie necessarie
import numpy as np
import matplotlib.pyplot as plt
# compose the NN model
import tensorflow as tf
from tensorflow import keras

from keras import backend, activations
from keras import optimizers, losses, metrics
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
from tensorflow.keras import backend as K
from tensorflow.keras.utils import get_custom_objects
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Introduzione
#
# In questo notebook è svolta l'intera esercitazione. Inoltre per semplicità alcuni risultati ottenuti sono riportati sottoforma di immagini senza rieffettuare ogni volta la costruzione e il training della Neural Networks (NN).

# %% [markdown]
# ## Es 11.1

# %% [markdown]
# In questa parte dell'esercitazione viene considerata la funzione:
#
# $$
# f(x)=2x+1
# $$
# L'obiettivo è quello di studiare la dipendenza della regressione lineare in funzione del numero di epoche $N_{\mathrm{epochs}}$, del numero di dati di train $N_{\mathrm{train}}$ e dal rumore $\sigma$ con il quale i dati sono stati "sporcati". Inizialmente il valore impostato è $\sigma = 0$.
#
# Si riporta di seguito la generazione dei dati esatti e di quelli che differiscono dal modello considerato. Questa parte verrà modificata ogni volta si voglia variare il numero di dati di train e la deviazione standard.

# %%
# target parameters of f(x) = m*x + b
m = 2 # slope
b = 1 # intersect

# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 1000)  #train data
x_valid = np.random.uniform(-1, 1, 100)   #data for the validation (c.a. 10% of train data)
x_valid.sort()
y_target = m * x_valid + b # ideal (target) linear function

sigma = 0. # noise standard deviation, for the moment it is absent
y_train = np.random.normal(m * x_train + b, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(m * x_valid + b, sigma)

# plot training and target dataset
plt.plot(x_valid, y_target, label = 'target data')
plt.scatter(x_valid, y_valid, color='r', label = 'validation data', marker = 'x')
plt.xlabel ('x')
plt.ylabel ('y')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Di seguito viene costruita una NN sequenziale costituita da un singolo neurone con l'obiettivo di effettuare la regressione lineare oggetto dell'esercizio. Come ottimizzatore è scelto lo Stochastic Gradient Discent e come funzione costo la Mean Squared Error.

# %%
# compose the NN model
model = tf.keras.Sequential()
model.add(Dense(1, input_shape=(1,)))

# compile the model choosing optimizer, loss and metrics objects
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# A questo punto si procede con il training e la validazione del modello costruito sui dati di training con l'obiettivo di trovare i pesi che vadano a minimizzare la funzione costo. Questa è la parte di codice che sarà modificata ogni volta per variare il numero di epoche.

# %%
# fit the model using training dataset
# report training progress against validation data
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=50,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/50
# 32/32 [==============================] - 0s 8ms/step - loss: 3.6232 - mse: 3.6232 - val_loss: 2.9715 - val_mse: 2.9715
# Epoch 2/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.1554 - mse: 2.1554 - val_loss: 1.8516 - val_mse: 1.8516
# Epoch 3/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.3433 - mse: 1.3433 - val_loss: 1.1827 - val_mse: 1.1827
# Epoch 4/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.8557 - mse: 0.8557 - val_loss: 0.7640 - val_mse: 0.7640
# Epoch 5/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.5516 - mse: 0.5516 - val_loss: 0.4951 - val_mse: 0.4951
# Epoch 6/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.3565 - mse: 0.3565 - val_loss: 0.3219 - val_mse: 0.3219
# Epoch 7/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.2314 - mse: 0.2314 - val_loss: 0.2081 - val_mse: 0.2081
# Epoch 8/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.1496 - mse: 0.1496 - val_loss: 0.1350 - val_mse: 0.1350
# Epoch 9/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0969 - mse: 0.0969 - val_loss: 0.0876 - val_mse: 0.0876
# Epoch 10/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0629 - mse: 0.0629 - val_loss: 0.0571 - val_mse: 0.0571
# Epoch 11/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0409 - mse: 0.0409 - val_loss: 0.0370 - val_mse: 0.0370
# Epoch 12/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0265 - mse: 0.0265 - val_loss: 0.0240 - val_mse: 0.0240
# Epoch 13/50
# 32/32 [==============================] - 0s 2ms/step - loss: 0.0172 - mse: 0.0172 - val_loss: 0.0155 - val_mse: 0.0155
# Epoch 14/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0101 - val_mse: 0.0101
# Epoch 15/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0072 - mse: 0.0072 - val_loss: 0.0065 - val_mse: 0.0065
# Epoch 16/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0047 - mse: 0.0047 - val_loss: 0.0042 - val_mse: 0.0042
# Epoch 17/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0030 - mse: 0.0030 - val_loss: 0.0028 - val_mse: 0.0028
# Epoch 18/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0020 - mse: 0.0020 - val_loss: 0.0018 - val_mse: 0.0018
# Epoch 19/50
# 32/32 [==============================] - 0s 1ms/step - loss: 0.0013 - mse: 0.0013 - val_loss: 0.0012 - val_mse: 0.0012
# Epoch 20/50
# 32/32 [==============================] - 0s 1ms/step - loss: 8.3459e-04 - mse: 8.3459e-04 - val_loss: 7.5497e-04 - val_mse: 7.5497e-04
# Epoch 21/50
# 32/32 [==============================] - 0s 1ms/step - loss: 5.4095e-04 - mse: 5.4095e-04 - val_loss: 4.9104e-04 - val_mse: 4.9104e-04
# Epoch 22/50
# 32/32 [==============================] - 0s 1ms/step - loss: 3.5183e-04 - mse: 3.5183e-04 - val_loss: 3.1666e-04 - val_mse: 3.1666e-04
# Epoch 23/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.2720e-04 - mse: 2.2720e-04 - val_loss: 2.0562e-04 - val_mse: 2.0562e-04
# Epoch 24/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.4737e-04 - mse: 1.4737e-04 - val_loss: 1.3299e-04 - val_mse: 1.3299e-04
# Epoch 25/50
# 32/32 [==============================] - 0s 1ms/step - loss: 9.5360e-05 - mse: 9.5360e-05 - val_loss: 8.5996e-05 - val_mse: 8.5996e-05
# Epoch 26/50
# 32/32 [==============================] - 0s 1ms/step - loss: 6.1541e-05 - mse: 6.1541e-05 - val_loss: 5.5685e-05 - val_mse: 5.5685e-05
# Epoch 27/50
# 32/32 [==============================] - 0s 1ms/step - loss: 3.9870e-05 - mse: 3.9870e-05 - val_loss: 3.5983e-05 - val_mse: 3.5983e-05
# Epoch 28/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.5787e-05 - mse: 2.5787e-05 - val_loss: 2.3333e-05 - val_mse: 2.3333e-05
# Epoch 29/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.6706e-05 - mse: 1.6706e-05 - val_loss: 1.5073e-05 - val_mse: 1.5073e-05
# Epoch 30/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0804e-05 - mse: 1.0804e-05 - val_loss: 9.7351e-06 - val_mse: 9.7351e-06
# Epoch 31/50
# 32/32 [==============================] - 0s 1ms/step - loss: 6.9781e-06 - mse: 6.9781e-06 - val_loss: 6.2569e-06 - val_mse: 6.2569e-06
# Epoch 32/50
# 32/32 [==============================] - 0s 1ms/step - loss: 4.4811e-06 - mse: 4.4811e-06 - val_loss: 4.0464e-06 - val_mse: 4.0464e-06
# Epoch 33/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.9011e-06 - mse: 2.9011e-06 - val_loss: 2.6274e-06 - val_mse: 2.6274e-06
# Epoch 34/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.8823e-06 - mse: 1.8823e-06 - val_loss: 1.7097e-06 - val_mse: 1.7097e-06
# Epoch 35/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.2250e-06 - mse: 1.2250e-06 - val_loss: 1.1112e-06 - val_mse: 1.1112e-06
# Epoch 36/50
# 32/32 [==============================] - 0s 1ms/step - loss: 7.9673e-07 - mse: 7.9673e-07 - val_loss: 7.2500e-07 - val_mse: 7.2500e-07
# Epoch 37/50
# 32/32 [==============================] - 0s 2ms/step - loss: 5.1984e-07 - mse: 5.1984e-07 - val_loss: 4.6808e-07 - val_mse: 4.6808e-07
# Epoch 38/50
# 32/32 [==============================] - 0s 1ms/step - loss: 3.3585e-07 - mse: 3.3585e-07 - val_loss: 3.0260e-07 - val_mse: 3.0260e-07
# Epoch 39/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.1682e-07 - mse: 2.1682e-07 - val_loss: 1.9685e-07 - val_mse: 1.9685e-07
# Epoch 40/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.4116e-07 - mse: 1.4116e-07 - val_loss: 1.2742e-07 - val_mse: 1.2742e-07
# Epoch 41/50
# 32/32 [==============================] - 0s 2ms/step - loss: 9.1226e-08 - mse: 9.1226e-08 - val_loss: 8.2033e-08 - val_mse: 8.2033e-08
# Epoch 42/50
# 32/32 [==============================] - 0s 1ms/step - loss: 5.8742e-08 - mse: 5.8742e-08 - val_loss: 5.3151e-08 - val_mse: 5.3151e-08
# Epoch 43/50
# 32/32 [==============================] - 0s 1ms/step - loss: 3.8011e-08 - mse: 3.8011e-08 - val_loss: 3.4240e-08 - val_mse: 3.4240e-08
# Epoch 44/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.4487e-08 - mse: 2.4487e-08 - val_loss: 2.2110e-08 - val_mse: 2.2110e-08
# Epoch 45/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.5824e-08 - mse: 1.5824e-08 - val_loss: 1.4262e-08 - val_mse: 1.4262e-08
# Epoch 46/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.0192e-08 - mse: 1.0192e-08 - val_loss: 9.1992e-09 - val_mse: 9.1992e-09
# Epoch 47/50
# 32/32 [==============================] - 0s 1ms/step - loss: 6.5994e-09 - mse: 6.5994e-09 - val_loss: 6.0224e-09 - val_mse: 6.0224e-09
# Epoch 48/50
# 32/32 [==============================] - 0s 1ms/step - loss: 4.3117e-09 - mse: 4.3117e-09 - val_loss: 3.8667e-09 - val_mse: 3.8667e-09
# Epoch 49/50
# 32/32 [==============================] - 0s 1ms/step - loss: 2.7614e-09 - mse: 2.7614e-09 - val_loss: 2.4941e-09 - val_mse: 2.4941e-09
# Epoch 50/50
# 32/32 [==============================] - 0s 1ms/step - loss: 1.7780e-09 - mse: 1.7780e-09 - val_loss: 1.6184e-09 - val_mse: 1.6184e-09

# %% [markdown]
# Di seguito è possibile valutare il modello su diversi dataset. Qui sono presi in considerazione i dati di validazione e quelli corretti. Vengono quindi stampati a schermo i valori della funzione costo e il valore dell' accuratezza.

# %%
# evaluate model
score = model.evaluate(x_valid, y_valid, batch_size=32, verbose=1)
# print performance
print('Evaluation model with the validation data:')
print('Test loss:', score[0])
print('Test accuracy:', score[1])

print('\n')
# evaluate model with the exact curve
score = model.evaluate(x_valid, y_target, batch_size=32, verbose=1)
# print performance
print('Evaluation model with the exact curve:')
print('Test loss:', score[0])
print('Test accuracy:', score[1])
# Out:
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6184e-09 - mse: 1.6184e-09
# Evaluation model with the validation data:
# Test loss: 1.618362555078079e-09
# Test accuracy: 1.618362555078079e-09
#
#
# 4/4 [==============================] - 0s 2ms/step - loss: 1.6184e-09 - mse: 1.6184e-09
# Evaluation model with the exact curve:
# Test loss: 1.618362555078079e-09
# Test accuracy: 1.618362555078079e-09

# %% [markdown]
# In conclusione è possibile ottenere due grafici che rappresentano rispettivamenete i valori della funzione costo per i dati di train e quelli di test in funzione del numero di epoche e una predizione effettuata con la NN appena testata.

# %%
# look into training history
# Plot training & validation loss values
plt.figure(figsize=(16,10))
plt.subplot(2,2,1)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss', fontsize = 15)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')

plt.subplot(2,2,2)
x_predicted = np.random.uniform(-1, 1, 100)
y_predicted = model.predict(x_predicted)
plt.scatter(x_predicted, y_predicted,color='r', label ='predicted data', marker = 'x')
plt.plot(x_valid, y_target, label = 'target data', color = 'green')
plt.title("Prediction", fontsize = 15)
plt.xlabel ('x')
plt.ylabel ('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Si nota che sono stati riportati solo i casi considerati significativi trascurando molti altri tentativi risultati simili ai precenti e poco rappresentativi. In conclusione è possibile affermare che la NN implementata siccome il modello è semplice rieesce ad avere un forte potere predittivo su dati poco rumorosi, però in alcuni casi estremi incorre in un overfitting dei dati.

# %% [markdown]
# ## Es 11.2

# %% [markdown]
# Lo scopo di questo esercio è quello di costruire una NN che sia in grado di effettuare un fit della funzione:
#
# $$
# f(x)=4-3x-2x^2+3x^3 \quad \text{con} \quad x \in [-1,1]\, .
# $$
# In questo esercizio sono stati variati i valori dei seguenti parametri:
#
# - il numero di hidden layers;
# - il numero di neuroni per layer;
# - la funzione di attivazione;
# - l'ottimizzatore;
# - la loss function.
#
# La costruzione della NN è stata effettuata considerando un numero fisso di dati di train e dati di test; nello specifico si sono considerati $10^4$ dati di train e $10^3$ dati di test/validation in modo tale che quelli di test fossero il $10\%$ di quelli di train. La procedura che si è considerata è stata quella di un progressivo aumento della complessità della rete (il numero di parametri) per studiare la bontà del fit dei dati di train e le capacità della rete di fare delle predizioni. La rete neurale considerata possiede un singolo neurone sul layer di input (poichè ho una sola variabile $x$ come input del problema) e di uno su quello di output (ho una sola variabile $f(x)$ in output).
#
# Si riportano di seguito la costruzione della NN e delle considerazioni euristiche al variare dei parametri precedentemente elencati. Le modifiche apportate per ottenere i diversi step implementativi non sono mostrate poichè sono riportati solo i risultati finali. Nelle tabelle sono riportati i parametri relativi ad ogni step dove i valori in grassetto rappresentano quelli che sono stati modificati rispetto al caso precedente.

# %%
# generate training inputs
np.random.seed(0)
x_train = np.random.uniform(-1, 1, 10000)
x_valid = np.random.uniform(-1, 1, 1000)
x_valid.sort()

y_target = 4 - 3*x_valid -2*x_valid**2 + 3*x_valid**3 # ideal (target) linear function

sigma = 0 # noise standard deviation, for the moment it is absent
y_train = np.random.normal(4 - 3*x_train -2*x_train**2 + 3*x_train**3, sigma) # actual measures from which we want to guess regression parameters
y_valid = np.random.normal(4 - 3*x_valid -2*x_valid**2 + 3*x_valid**3, sigma)

# %%
# compose the NN model
model = Sequential()
model.add(Dense(1, input_shape=(1,)))
model.add(Dense(20, activation='tanh'))
model.add(Dense(1,))

# compile the model
model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 2
# _________________________________________________________________
# dense_2 (Dense)              (None, 20)                40
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 63
# Trainable params: 63
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(x=x_train, y=y_train, 
          batch_size=32, epochs=30,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, y_valid))
# Out:
# Epoch 1/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.6482 - mse: 0.6482 - val_loss: 0.3837 - val_mse: 0.3837
# Epoch 2/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.3131 - mse: 0.3131 - val_loss: 0.2560 - val_mse: 0.2560
# Epoch 3/30
# 313/313 [==============================] - 0s 947us/step - loss: 0.2126 - mse: 0.2126 - val_loss: 0.1620 - val_mse: 0.1620
# Epoch 4/30
# 313/313 [==============================] - 0s 958us/step - loss: 0.1077 - mse: 0.1077 - val_loss: 0.0602 - val_mse: 0.0602
# Epoch 5/30
# 313/313 [==============================] - 0s 986us/step - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0323 - val_mse: 0.0323
# Epoch 6/30
# 313/313 [==============================] - 0s 984us/step - loss: 0.0298 - mse: 0.0298 - val_loss: 0.0262 - val_mse: 0.0262
# Epoch 7/30
# 313/313 [==============================] - 0s 911us/step - loss: 0.0261 - mse: 0.0261 - val_loss: 0.0234 - val_mse: 0.0234
# Epoch 8/30
# 313/313 [==============================] - 0s 923us/step - loss: 0.0237 - mse: 0.0237 - val_loss: 0.0211 - val_mse: 0.0211
# Epoch 9/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0218 - mse: 0.0218 - val_loss: 0.0193 - val_mse: 0.0193
# Epoch 10/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0202 - mse: 0.0202 - val_loss: 0.0180 - val_mse: 0.0180
# Epoch 11/30
# 313/313 [==============================] - 0s 969us/step - loss: 0.0188 - mse: 0.0188 - val_loss: 0.0167 - val_mse: 0.0167
# Epoch 12/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0174 - mse: 0.0174 - val_loss: 0.0156 - val_mse: 0.0156
# Epoch 13/30
# 313/313 [==============================] - 0s 956us/step - loss: 0.0163 - mse: 0.0163 - val_loss: 0.0146 - val_mse: 0.0146
# Epoch 14/30
# 313/313 [==============================] - 0s 966us/step - loss: 0.0154 - mse: 0.0154 - val_loss: 0.0137 - val_mse: 0.0137
# Epoch 15/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0146 - mse: 0.0146 - val_loss: 0.0132 - val_mse: 0.0132
# Epoch 16/30
# 313/313 [==============================] - 0s 964us/step - loss: 0.0139 - mse: 0.0139 - val_loss: 0.0124 - val_mse: 0.0124
# Epoch 17/30
# 313/313 [==============================] - 0s 906us/step - loss: 0.0132 - mse: 0.0132 - val_loss: 0.0118 - val_mse: 0.0118
# Epoch 18/30
# 313/313 [==============================] - 0s 884us/step - loss: 0.0126 - mse: 0.0126 - val_loss: 0.0113 - val_mse: 0.0113
# Epoch 19/30
# 313/313 [==============================] - 0s 894us/step - loss: 0.0120 - mse: 0.0120 - val_loss: 0.0108 - val_mse: 0.0108
# Epoch 20/30
# 313/313 [==============================] - 0s 878us/step - loss: 0.0115 - mse: 0.0115 - val_loss: 0.0104 - val_mse: 0.0104
# Epoch 21/30
# 313/313 [==============================] - 0s 986us/step - loss: 0.0111 - mse: 0.0111 - val_loss: 0.0100 - val_mse: 0.0100
# Epoch 22/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0107 - mse: 0.0107 - val_loss: 0.0097 - val_mse: 0.0097
# Epoch 23/30
# 313/313 [==============================] - 0s 951us/step - loss: 0.0103 - mse: 0.0103 - val_loss: 0.0093 - val_mse: 0.0093
# Epoch 24/30
# 313/313 [==============================] - 0s 916us/step - loss: 0.0100 - mse: 0.0100 - val_loss: 0.0090 - val_mse: 0.0090
# Epoch 25/30
# 313/313 [==============================] - 0s 934us/step - loss: 0.0097 - mse: 0.0097 - val_loss: 0.0088 - val_mse: 0.0088
# Epoch 26/30
# 313/313 [==============================] - 0s 931us/step - loss: 0.0094 - mse: 0.0094 - val_loss: 0.0086 - val_mse: 0.0086
# Epoch 27/30
# 313/313 [==============================] - 0s 974us/step - loss: 0.0091 - mse: 0.0091 - val_loss: 0.0084 - val_mse: 0.0084
# Epoch 28/30
# 313/313 [==============================] - 0s 910us/step - loss: 0.0088 - mse: 0.0088 - val_loss: 0.0081 - val_mse: 0.0081
# Epoch 29/30
# 313/313 [==============================] - 0s 970us/step - loss: 0.0086 - mse: 0.0086 - val_loss: 0.0079 - val_mse: 0.0079
# Epoch 30/30
# 313/313 [==============================] - 0s 1ms/step - loss: 0.0084 - mse: 0.0084 - val_loss: 0.0077 - val_mse: 0.0077

# %% [markdown]
# Successivamente considerando l'ultimo come il modello migliore, si è provato a produrre dei dati rumorosi con una $\sigma = 0.3$ per testare la capacità predittiva della rete neurale. Il risultato è riportato di seguito. Si può notare che la previsione effettutua risulta essere ottima. Tuttavia provando ad aumentarla questa previsione diventa prograssivamente peggiore.

# %% [markdown]
# In conclusione è possibile effettuare un ulteriore test per valutare la capacità predittiva della NN, cioè testare la previsione di dati fuori dal range in cui è stato effettuato il training. Nel seguente grafico sono riportare le previsioni della rete sia all'interno sia all'esterno del range di training con i parametri utilizzati nel punto 10. Si osserva che la NN non è in grado di fare previsione corrette al di fuori del range in cui è avvenuto il training.

# %% [markdown]
# ## Es 11.3

# %% [markdown]
# Questa parte dell'esercitazione consiste nel costruire una rete neurale in grado di effettuare un fit della seguente funzione trigonometrica 2D:
#
# $$
# f(x,y) = \sin(x^2+y^2) \quad \text{con} \quad x \in [-3/2,3/2] \quad \text{e} \quad  y \in [-3/2,3/2]\, .
# $$
# La rete neurale che viene considerata è notevolmente più complesse delle precedenti data la maggior difficiltà del problema. Di seguito sono riportati i risultati ottenuti per la miglior NN identificata per risolvere il problema e non i diversi tentativi necessari per costruirla. La rete è costituita da:
#
# Numero del layer	Numero di neuroni	Funzione di attivazione
# 1°	2	/
# 2°	60	relu
# 3°	50	tanh
# 4°	20	sigmoid
# 5°	1	/
#
# I parametri utilizzati sono riportati nella seguente tabella:
#
# Numero di dati di train	Numero di dati di test	Numero di hidden layers	Numero di parametri totali	Ottimizzatore	Loss Fuction	Numero di epoche
# 20000	2000	3	4277	Stochastic Gradient Discend	Mean Squared Error	100

# %%
def sin2d(x):
    return np.sin(x[:,0]**2+x[:,1]**2)

n_train = 20000 #numero dati di training
n_valid = 2000  #numero dati di validation

x_train = np.zeros((n_train, 2))    
z_train = np.zeros((n_train, 1))  

x_valid = np.zeros((n_valid, 2))
z_valid = np.zeros((n_valid, 1))

x_train[:,0] = np.random.uniform(-3./2., 3./2., n_train)
x_train[:,1] = np.random.uniform(-3./2., 3./2., n_train)

x_valid[:,0] = np.random.uniform(-3./2., 3./2., n_valid)
x_valid[:,1] = np.random.uniform(-3./2., 3./2., n_valid)
z_target= sin2d(x_valid)

sigma = 0.2
z_train = np.random.normal(sin2d(x_train), sigma)
z_valid = np.random.normal(sin2d(x_valid), sigma)

# %%
model = Sequential()

model.add(Dense(2, input_shape=(2,)))

model.add(Dense(60, activation='relu'))
model.add(Dense(50, activation='tanh'))
model.add(Dense(20, activation='sigmoid'))

model.add(Dense(1))


model.compile(optimizer='sgd', loss='mse', metrics=['mse'])
model.summary()

history = model.fit(x=x_train, y=z_train, 
          batch_size=32, epochs=100,
          shuffle=True, # a good idea is to shuffle input before at each epoch
          validation_data=(x_valid, z_valid))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 2)                 6
# _________________________________________________________________
# dense_5 (Dense)              (None, 60)                180
# _________________________________________________________________
# dense_6 (Dense)              (None, 50)                3050
# _________________________________________________________________
# dense_7 (Dense)              (None, 20)                1020
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 21
# =================================================================
# Total params: 4,277
# Trainable params: 4,277
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.2069 - mse: 0.2069 - val_loss: 0.1926 - val_mse: 0.1926
# Epoch 2/100
# 625/625 [==============================] - 1s 985us/step - loss: 0.1861 - mse: 0.1861 - val_loss: 0.1901 - val_mse: 0.1901
# Epoch 3/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1844 - mse: 0.1844 - val_loss: 0.1888 - val_mse: 0.1888
# Epoch 4/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1822 - mse: 0.1822 - val_loss: 0.1857 - val_mse: 0.1857
# Epoch 5/100
# 625/625 [==============================] - 1s 965us/step - loss: 0.1797 - mse: 0.1797 - val_loss: 0.1833 - val_mse: 0.1833
# Epoch 6/100
# 625/625 [==============================] - 1s 963us/step - loss: 0.1771 - mse: 0.1771 - val_loss: 0.1811 - val_mse: 0.1811
# Epoch 7/100
# 625/625 [==============================] - 1s 974us/step - loss: 0.1737 - mse: 0.1737 - val_loss: 0.1768 - val_mse: 0.1768
# Epoch 8/100
# 625/625 [==============================] - 1s 955us/step - loss: 0.1696 - mse: 0.1696 - val_loss: 0.1723 - val_mse: 0.1723
# Epoch 9/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1646 - mse: 0.1646 - val_loss: 0.1675 - val_mse: 0.1675
# Epoch 10/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1588 - mse: 0.1588 - val_loss: 0.1613 - val_mse: 0.1613
# Epoch 11/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1530 - mse: 0.1530 - val_loss: 0.1549 - val_mse: 0.1549
# Epoch 12/100
# 625/625 [==============================] - 1s 990us/step - loss: 0.1472 - mse: 0.1472 - val_loss: 0.1499 - val_mse: 0.1499
# Epoch 13/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1420 - mse: 0.1420 - val_loss: 0.1439 - val_mse: 0.1439
# Epoch 14/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1369 - mse: 0.1369 - val_loss: 0.1397 - val_mse: 0.1397
# Epoch 15/100
# 625/625 [==============================] - 1s 998us/step - loss: 0.1322 - mse: 0.1322 - val_loss: 0.1353 - val_mse: 0.1353
# Epoch 16/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1273 - mse: 0.1273 - val_loss: 0.1298 - val_mse: 0.1298
# Epoch 17/100
# 625/625 [==============================] - 1s 974us/step - loss: 0.1215 - mse: 0.1215 - val_loss: 0.1230 - val_mse: 0.1230
# Epoch 18/100
# 625/625 [==============================] - 1s 987us/step - loss: 0.1156 - mse: 0.1156 - val_loss: 0.1172 - val_mse: 0.1172
# Epoch 19/100
# 625/625 [==============================] - 1s 943us/step - loss: 0.1096 - mse: 0.1096 - val_loss: 0.1115 - val_mse: 0.1115
# Epoch 20/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.1030 - mse: 0.1030 - val_loss: 0.1031 - val_mse: 0.1031
# Epoch 21/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0965 - mse: 0.0965 - val_loss: 0.0984 - val_mse: 0.0984
# Epoch 22/100
# 625/625 [==============================] - 1s 975us/step - loss: 0.0906 - mse: 0.0906 - val_loss: 0.0905 - val_mse: 0.0905
# Epoch 23/100
# 625/625 [==============================] - 1s 990us/step - loss: 0.0847 - mse: 0.0847 - val_loss: 0.0851 - val_mse: 0.0851
# Epoch 24/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0793 - mse: 0.0793 - val_loss: 0.0792 - val_mse: 0.0792
# Epoch 25/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0743 - mse: 0.0743 - val_loss: 0.0769 - val_mse: 0.0769
# Epoch 26/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0698 - mse: 0.0698 - val_loss: 0.0723 - val_mse: 0.0723
# Epoch 27/100
# 625/625 [==============================] - 1s 969us/step - loss: 0.0660 - mse: 0.0660 - val_loss: 0.0663 - val_mse: 0.0663
# Epoch 28/100
# 625/625 [==============================] - 1s 949us/step - loss: 0.0628 - mse: 0.0628 - val_loss: 0.0653 - val_mse: 0.0653
# Epoch 29/100
# 625/625 [==============================] - 1s 987us/step - loss: 0.0597 - mse: 0.0597 - val_loss: 0.0626 - val_mse: 0.0626
# Epoch 30/100
# 625/625 [==============================] - 1s 947us/step - loss: 0.0573 - mse: 0.0573 - val_loss: 0.0582 - val_mse: 0.0582
# Epoch 31/100
# 625/625 [==============================] - 1s 986us/step - loss: 0.0553 - mse: 0.0553 - val_loss: 0.0557 - val_mse: 0.0557
# Epoch 32/100
# 625/625 [==============================] - 1s 938us/step - loss: 0.0532 - mse: 0.0532 - val_loss: 0.0553 - val_mse: 0.0553
# Epoch 33/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0518 - mse: 0.0518 - val_loss: 0.0524 - val_mse: 0.0524
# Epoch 34/100
# 625/625 [==============================] - 1s 971us/step - loss: 0.0503 - mse: 0.0503 - val_loss: 0.0507 - val_mse: 0.0507
# Epoch 35/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0493 - mse: 0.0493 - val_loss: 0.0500 - val_mse: 0.0500
# Epoch 36/100
# 625/625 [==============================] - 1s 981us/step - loss: 0.0482 - mse: 0.0482 - val_loss: 0.0480 - val_mse: 0.0480
# Epoch 37/100
# 625/625 [==============================] - 1s 966us/step - loss: 0.0474 - mse: 0.0474 - val_loss: 0.0477 - val_mse: 0.0477
# Epoch 38/100
# 625/625 [==============================] - 1s 995us/step - loss: 0.0468 - mse: 0.0468 - val_loss: 0.0467 - val_mse: 0.0467
# Epoch 39/100
# 625/625 [==============================] - 1s 998us/step - loss: 0.0460 - mse: 0.0460 - val_loss: 0.0472 - val_mse: 0.0472
# Epoch 40/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0456 - mse: 0.0456 - val_loss: 0.0468 - val_mse: 0.0468
# Epoch 41/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0452 - mse: 0.0452 - val_loss: 0.0462 - val_mse: 0.0462
# Epoch 42/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0447 - mse: 0.0447 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 43/100
# 625/625 [==============================] - 1s 983us/step - loss: 0.0446 - mse: 0.0446 - val_loss: 0.0453 - val_mse: 0.0453
# Epoch 44/100
# 625/625 [==============================] - 1s 961us/step - loss: 0.0441 - mse: 0.0441 - val_loss: 0.0440 - val_mse: 0.0440
# Epoch 45/100
# 625/625 [==============================] - 1s 959us/step - loss: 0.0438 - mse: 0.0438 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 46/100
# 625/625 [==============================] - 1s 989us/step - loss: 0.0437 - mse: 0.0437 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 47/100
# 625/625 [==============================] - 1s 980us/step - loss: 0.0436 - mse: 0.0436 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 48/100
# 625/625 [==============================] - 1s 949us/step - loss: 0.0432 - mse: 0.0432 - val_loss: 0.0445 - val_mse: 0.0445
# Epoch 49/100
# 625/625 [==============================] - 1s 947us/step - loss: 0.0431 - mse: 0.0431 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 50/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0430 - mse: 0.0430 - val_loss: 0.0431 - val_mse: 0.0431
# Epoch 51/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0428 - mse: 0.0428 - val_loss: 0.0424 - val_mse: 0.0424
# Epoch 52/100
# 625/625 [==============================] - 1s 973us/step - loss: 0.0429 - mse: 0.0429 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 53/100
# 625/625 [==============================] - 1s 946us/step - loss: 0.0427 - mse: 0.0427 - val_loss: 0.0451 - val_mse: 0.0451
# Epoch 54/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0426 - mse: 0.0426 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 55/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0424 - mse: 0.0424 - val_loss: 0.0426 - val_mse: 0.0426
# Epoch 56/100
# 625/625 [==============================] - 1s 959us/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 57/100
# 625/625 [==============================] - 1s 952us/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 58/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 59/100
# 625/625 [==============================] - 1s 967us/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0433 - val_mse: 0.0433
# Epoch 60/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0423 - mse: 0.0423 - val_loss: 0.0423 - val_mse: 0.0423
# Epoch 61/100
# 625/625 [==============================] - 1s 956us/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 62/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0422 - mse: 0.0422 - val_loss: 0.0421 - val_mse: 0.0421
# Epoch 63/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0429 - val_mse: 0.0429
# Epoch 64/100
# 625/625 [==============================] - 1s 955us/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0447 - val_mse: 0.0447
# Epoch 65/100
# 625/625 [==============================] - 1s 969us/step - loss: 0.0420 - mse: 0.0420 - val_loss: 0.0437 - val_mse: 0.0437
# Epoch 66/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 67/100
# 625/625 [==============================] - 1s 968us/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 68/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0417 - val_mse: 0.0417
# Epoch 69/100
# 625/625 [==============================] - 1s 963us/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 70/100
# 625/625 [==============================] - 1s 992us/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0410 - val_mse: 0.0410
# Epoch 71/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0421 - val_mse: 0.0421
# Epoch 72/100
# 625/625 [==============================] - 1s 957us/step - loss: 0.0419 - mse: 0.0419 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 73/100
# 625/625 [==============================] - 1s 972us/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0426 - val_mse: 0.0426
# Epoch 74/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0423 - val_mse: 0.0423
# Epoch 75/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0428 - val_mse: 0.0428
# Epoch 76/100
# 625/625 [==============================] - 1s 973us/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0426 - val_mse: 0.0426
# Epoch 77/100
# 625/625 [==============================] - 1s 984us/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0448 - val_mse: 0.0448
# Epoch 78/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0418 - mse: 0.0418 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 79/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0413 - val_mse: 0.0413
# Epoch 80/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0425 - val_mse: 0.0425
# Epoch 81/100
# 625/625 [==============================] - 1s 949us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0432 - val_mse: 0.0432
# Epoch 82/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0418 - val_mse: 0.0418
# Epoch 83/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0417 - mse: 0.0417 - val_loss: 0.0422 - val_mse: 0.0422
# Epoch 84/100
# 625/625 [==============================] - 1s 972us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 85/100
# 625/625 [==============================] - 1s 977us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0419 - val_mse: 0.0419
# Epoch 86/100
# 625/625 [==============================] - 1s 961us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0456 - val_mse: 0.0456
# Epoch 87/100
# 625/625 [==============================] - 1s 964us/step - loss: 0.0416 - mse: 0.0416 - val_loss: 0.0417 - val_mse: 0.0417
# Epoch 88/100
# 625/625 [==============================] - 1s 965us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0419 - val_mse: 0.0419
# Epoch 89/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0417 - val_mse: 0.0417
# Epoch 90/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0415 - val_mse: 0.0415
# Epoch 91/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0415 - val_mse: 0.0415
# Epoch 92/100
# 625/625 [==============================] - 1s 994us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0412 - val_mse: 0.0412
# Epoch 93/100
# 625/625 [==============================] - 1s 964us/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0425 - val_mse: 0.0425
# Epoch 94/100
# 625/625 [==============================] - 1s 983us/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0419 - val_mse: 0.0419
# Epoch 95/100
# 625/625 [==============================] - 1s 990us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0424 - val_mse: 0.0424
# Epoch 96/100
# 625/625 [==============================] - 1s 960us/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0441 - val_mse: 0.0441
# Epoch 97/100
# 625/625 [==============================] - 1s 948us/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0420 - val_mse: 0.0420
# Epoch 98/100
# 625/625 [==============================] - 1s 953us/step - loss: 0.0414 - mse: 0.0414 - val_loss: 0.0409 - val_mse: 0.0409
# Epoch 99/100
# 625/625 [==============================] - 1s 995us/step - loss: 0.0415 - mse: 0.0415 - val_loss: 0.0430 - val_mse: 0.0430
# Epoch 100/100
# 625/625 [==============================] - 1s 1ms/step - loss: 0.0413 - mse: 0.0413 - val_loss: 0.0413 - val_mse: 0.0413

# %%
plt.figure(figsize=(6,4))
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss', fontsize = 15)
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='best')

n_predicted = 2000
x_predicted = np.zeros((n_predicted, 2))    #matrice (x,y)
z_predicted = np.zeros((n_predicted))
x_predicted[:,0] = np.random.uniform(-4./2., 4./2., n_predicted)
x_predicted[:,1] = np.random.uniform(-4./2., 4./2., n_predicted)
z_predicted= model.predict(x_predicted)

n_train = 20000 #numero dati di training
n_valid = 2000  #numero dati di validation

fig = plt.figure()
ax = Axes3D(fig)
x_valid[:,0] = np.random.uniform(-4./2., 4./2., n_valid)
x_valid[:,1] = np.random.uniform(-4./2., 4./2., n_valid)
z_target= sin2d(x_valid)
ax.scatter(x_valid[:,0], x_valid[:,1],z_target, c='green', marker='.', label = 'Validazion data in/out range')
ax.scatter(x_predicted[:,0], x_predicted[:,1],z_predicted, c='red', marker='.',label = 'Predicted data')
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
ax.legend()
ax.set_title("Prevision", fontsize = 15)
plt.show()

# %% [markdown]
# Nell' ultimo grafico sono riportate le previsioni della rete neurale sia all'interno ($[-3/2,3/2]$) che all'esterno ($[-4/2,4/2]$) del range di training. Si può notare che le previsioni all'interno del range sono ottime, ma al di fuori come nel caso precedente le previsioni peggiorano fino a sbagliare completamente tanto più ci si allontana dal range di training.
